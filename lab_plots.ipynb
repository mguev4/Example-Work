# %% [markdown]
# # Welcome to Lab_Plots! 🕵🏻‍♂️ 📊 🕵🏻‍♀️
#
# Fun fact: Every employee at the University of Illinois is a "public employee" and all public employee salaries are [publicly available online](https://www.bot.uillinois.edu/resources/gray_book) -- we have curated this data in a cleaned dataset for you to explore!  This includes data about every professor, administrator, and football coach!
#
# The goal of this lab is to work with **real UIUC salary data** to explore its properties, answer important questions, and to think about the implications of collecting and analyzing this data.  Throughout the lab, it is important to think about being a critical consumer of data who can not only use statistics and programming to analyze data, but can also think about the **"why"** part of data science both in the classroom and in the world. Let’s get started!
#
# In this lab, you will:
# - Work with real UIUC salary data to explore some of the statistics that we talked about in lecture: mean, median, standard deviation, etc.
# - Practice creating plots to **visualize quantitative data**: boxplots and histograms.
# - See how data science can be used in the real world to think about important issues through written individual reflections and discussions with your group.
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab TA, the CAs, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# First name is enough, we'll know who they are! :)
ta_name = "Jake"
ca1_name = "Soph"
ca2_name = "Maddy"
ca3_name = ""

# Work with your group again this week! 
#
# QOTD to Ask Your Group: "What was your favorite childhood game?"
partner1_name = "Esther"
partner1_netid = ""
partner1_fav_game = "Club Peqguin"

partner2_name = "Savanah"
partner2_netid = ""
partner2_fav_game = "Just Dance"

partner3_name = ""
partner3_netid = ""
partner3_fav_game = ""

# Which lab section are you in? Record it below! It should start with a Y and have 
# 2 numbers after the Y. If you're unsure - ask your TA/CAs!
lab_section = "Y01"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Setup: Import the Graybook Dataset
#
# The "Gray Book" is historical term for the book of "Academic and Administrative Appointments".  As a public university, all positions (including job title, tenure status, and salary) at UIUC are publicly approved by the Board of Trustees.  After approval, they are published publicly at [https://www.bot.uillinois.edu/resources/gray_book](https://www.bot.uillinois.edu/resources/gray_book).
#
# We have parsed the HTML tables and done a little data cleaning for you. The "Graybook Dataset" provided here includes all faculty (except for the Division of Collegiate Athletics, for salary outlier reasons) at the University of Illinois, based on the **2022-2023 Graybook report**.  A CSV version of this dataset is available at the following URL:
#
# ```
# https://waf.cs.illinois.edu/discovery/graybook.csv
# ```
#
# Import `pandas` and load this dataset into a DataFrame, `df`:

# %%
import pandas as pd
df = pd.read_csv ("https://waf.cs.illinois.edu/discovery/graybook.csv")
df
# Out:
#                   Employee Name            Primary Job Title  \
# 0         Gerstenecker, David G          DIR OF INFO TECHNOL
# 1           Henry, Joshua Keith       ASSOC DIR INFO TECHNOL
# 2               Meyer, Donald L             SR NETWORK ANLYS
# 3         Winter-Nelson, Alex E                         PROF
# 4     Axtman-Barker, Pamela Ann                        INSTR
# ...                         ...                          ...
# 6283          Chambers, Sonya L  EXEC DIR STRATG INITIATIVES
# 6284            Garrick, Sean C  VC FOR DVSTY, EQUITY & INCL
# 6285     Guerra Perez, Gioconda      EXEC ASSOC VC FOR DVSTY
# 6286       VanDuyne, Adam Jareb          EXEC DIR FIN & ADMN
# 6287           Wantland, Ross A      DIR OF CURR DEVL & EDUC
#
#                     Department Name College Code  \
# 0          ACES Technology Services           KL
# 1          ACES Technology Services           KL
# 2          ACES Technology Services           KL
# 3          Agr & Consumer Economics           KL
# 4       Ag Ldrshp Educ Comm Program           KL
# ...                             ...          ...
# 6283  Vice Chancellor for Diversity           NV
# 6284  Vice Chancellor for Diversity           NV
# 6285  Vice Chancellor for Diversity           NV
# 6286  Vice Chancellor for Diversity           NV
# 6287  Vice Chancellor for Diversity           NV
#
#                        College Name  Present FTE  Proposed FTE  \
# 0      Agr, Consumer & Env Sciences          1.0           1.0
# 1      Agr, Consumer & Env Sciences          1.0           1.0
# 2      Agr, Consumer & Env Sciences          1.0           1.0
# 3      Agr, Consumer & Env Sciences          1.0           1.0
# 4      Agr, Consumer & Env Sciences          1.0           1.0
# ...                             ...          ...           ...
# 6283  Vice Chancellor for Diversity          1.0           1.0
# 6284  Vice Chancellor for Diversity          1.0           1.0
# 6285  Vice Chancellor for Diversity          1.0           1.0
# 6286  Vice Chancellor for Diversity          1.0           1.0
# 6287  Vice Chancellor for Diversity          1.0           1.0
#
#       Present Salary  Proposed Salary Tenure Empl Class  \
# 0          109670.28        112412.04    NaN         BA
# 1           83701.83         88723.94    NaN         BA
# 2           92692.76         96400.47    NaN         BA
# 3          193532.64        204244.60      A         AA
# 4           75000.00         75000.00    NaN         AL
# ...              ...              ...    ...        ...
# 6283       169500.00        176280.00    NaN         BA
# 6284       351778.94        364091.20    NaN         BA
# 6285       187250.00        195676.25    NaN         BA
# 6286       147200.00        153824.00    NaN         BA
# 6287        98860.00        102814.40    NaN         BA
#
#                              Secondary Job Titles  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3     ['DIR, ADMI', 'ASSOC DEAN FOR INATL PRGMS']
# 4                                             NaN
# ...                                           ...
# 6283                                          NaN
# 6284                                          NaN
# 6285                                          NaN
# 6286                                          NaN
# 6287                                          NaN
#
#                              Secondary Department Names
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     ['ADM Institute for PHL', 'Agr, Consumer & Env...
# 4                                                   NaN
# ...                                                 ...
# 6283                                                NaN
# 6284                                                NaN
# 6285                                                NaN
# 6286                                                NaN
# 6287                                                NaN
#
# [6288 rows x 13 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Loading in Graybook ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars()), "Load the dataset into the variable named `df`."
assert ( len(df) == 6288 ), "This is not the Graybook dataset you're looking for."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 1: Exploratory Data Analysis (EDA)
#
# As discussed in lecture, the first step of any data analysis is to **get familiar** with your dataset.  Think about what this data can tell you and what variables are included.  Data scientists always start with this step.
#
# Let’s do some general **exploratory data analysis** to feel out our dataset.  Before you do any calculations, ponder this question:

# %% [markdown]
# ### Initial Guess
#
# **What do you estimate the average salary of all UIUC Faculty to be?**

# %% [markdown]
# $90,000

# %% [markdown]
# ### Part 1.1: Descriptive Statistics
#
# Our Graybook Dataset contains both the `Present Salary` and `Proposed Salary` of employees at U of I. For now, we're only interested in the `Present Salary` column.
#
# Using `df`, find the following information in the cells below.  In these cells, and ALL cells throughout all lab notebooks, you must always **both calculate AND display** your result.  Only storing the variable, without displaying it, will not earn credit for this and every cell in the notebook.
#
# Find the following using `df` in the following four cells:
#
# 1. The number of faculty at UIUC, stored in the variable `num_employee` (Hint: each row is an employee!)
# 2. The **mean** present salary, storing in the variable `mean_sal`
# 3. The **median** present salary, storing in the variable `median_sal`
# 4. The **standard deviation** of present salary, storing in the variable `std_sal`

# %%
num_employee= len(df)
num_employee
# Out:
# 6288

# %%
mean_sal= df["Present Salary"].mean()
mean_sal.item()
# Out:
# 104221.36810591603

# %%
median_sal= df["Present Salary"].median()
median_sal.item()
# Out:
# 87975.0

# %%
std_sal= df["Present Salary"].std()
std_sal.item()
# Out:
# 111699.42003675704

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math

x = mean_sal + median_sal + std_sal
assert( num_employee == 6288 ), "Your calculations of the number of employees is incorrect."
assert( math.isclose(x, 303895.7881426731) ), "Your calculations of mean, median, or standard deviation is incorrect."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Visual Displays of Data: A Key Part of EDA!
#
# Now, we are a bit more familiar with the dataset through summary statistics. Looking at overall descriptive statistics helps us summarize all of the observations in a column, rather than having to scroll through all of the observations!  However, descriptive statistics alone often don’t tell the whole story. This is where having tools for **visualizing statistics** comes in handy.

# %% [markdown]
# ### Part 1.2: Boxplots and Histograms
#
# Next, let’s look at two simple, yet powerful visualizations: the **boxplot** and the **histogram**!
#
# Generate a **boxplot** of the `Present Salary` column.

# %%
df["Present Salary"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Generate a **histogram** of the `Present Salary` column.

# %%
df["Present Salary"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ###  Part 1.3: Remove the Outliers
#
# These visualizations that you just created look different than any that you saw in lecture! In class we learned how to calculate outliers mathematically using Q1, Q3, and the IQR. Create a new DataFrame, `df_without_outliers`, by removing all employees whose `Present Salary` is an outlier.
#
# **Hint**: You can find Q1 and Q3 in Python using the `.quantile()` function. Once you have these numbers, look in your notebook to see the conditions for high and low outliers and write a complex conditional to select the rows where the `Present Salary` is not an outlier.

# %%
# Use this cell to calculate and display Q1:
Q1 = df["Present Salary"].quantile(0.25)
Q1.item()
# Out:
# 64960.95

# %%
# Use this cell to calculate and display Q3:
Q3= df["Present Salary"].quantile(0.75)
Q3.item()
# Out:
# 124473.675

# %%
# Use this cell to calculate and display the IQR:
IQR= Q3.item()- Q1.item()
IQR
# Out:
# 59512.725000000006

# %%
# Use this cell to calculate and display the lower cutoff values for the outliers:
LOWER_CUTOFF= (Q3-(1.5*IQR)).item()
LCUTOFF_VALUE= df[df["Present Salary"]<LOWER_CUTOFF]
LCUTOFF_VALUE
# Out:
#                  Employee Name         Primary Job Title  \
# 165    Fleming, Stephen Andrew             ADJ ASST PROF
# 264           Cox, Joan Carrie  VST EXT OUTR ASSOC, NREE
# 528        Plawer, Wanda Susan       COORD RES PRGM PROJ
# 537        Born, Amy Nicolette               RSRSC PRFNL
# 542   Cockerham, Annalisa Jane               RSRSC PRFNL
# ...                        ...                       ...
# 5484         Cragin, Melissa H                 ASST PROF
# 5897          Beccue, Nathan J         NATURAL AREAS MGR
# 6016          Valentine, Helen                  DIR, ACP
# 6067            Clasby, Ryan P         POSTDOC RES ASSOC
# 6069   Filippini, Heather Rose  ASST FACILTS SECRTY OFCR
#
#                      Department Name College Code  \
# 165                  Animal Sciences           KL
# 264            Cooperative Extension           KL
# 528   Food Science & Human Nutrition           KL
# 537    Human Dvlpmt & Family Studies           KL
# 542    Human Dvlpmt & Family Studies           KL
# ...                              ...          ...
# 5484            Information Sciences           LP
# 5897  Allerton Park & Retreat Center           NL
# 6016             Animal Care Program           NE
# 6067                     OVCRI Admin           NE
# 6069                     OVCRI Admin           NE
#
#                         College Name  Present FTE  Proposed FTE  \
# 165     Agr, Consumer & Env Sciences         0.00          0.00
# 264     Agr, Consumer & Env Sciences         0.00          0.00
# 528     Agr, Consumer & Env Sciences         0.50          0.50
# 537     Agr, Consumer & Env Sciences         0.70          0.70
# 542     Agr, Consumer & Env Sciences         0.60          0.60
# ...                              ...          ...           ...
# 5484  School of Information Sciences         0.00          0.00
# 5897         VC Admin and Operations         0.51          0.51
# 6016  VC for Research and Innovation         0.10          1.00
# 6067  VC for Research and Innovation         0.20          0.20
# 6069  VC for Research and Innovation         0.00          0.00
#
#       Present Salary  Proposed Salary Tenure Empl Class Secondary Job Titles  \
# 165             0.00             0.00    NaN         AB                  NaN
# 264          7500.00          7500.00    NaN         BA                  NaN
# 528         25594.73         26733.70    NaN         BA                  NaN
# 537         32894.53         34210.31    NaN         BA                  NaN
# 542         26491.16         27550.81    NaN         BA                  NaN
# ...              ...              ...    ...        ...                  ...
# 5484            0.00             0.00    NaN         AM                  NaN
# 5897        24921.88         25918.76    NaN         BA                  NaN
# 6016        23000.00        230000.00    NaN         BA                  NaN
# 6067        11000.00         11440.00    NaN         PA                  NaN
# 6069         6000.00          6000.00    NaN         BA                  NaN
#
#      Secondary Department Names
# 165                         NaN
# 264                         NaN
# 528                         NaN
# 537                         NaN
# 542                         NaN
# ...                         ...
# 5484                        NaN
# 5897                        NaN
# 6016                        NaN
# 6067                        NaN
# 6069                        NaN
#
# [251 rows x 13 columns]

# %%
# Use this cell to calculate and display the upper cutoff value for the outliers:
HIGHER_CUTOFF= (Q3+(1.5*IQR)).item()
HCUTOFF_VALUE= df[df["Present Salary"]>HIGHER_CUTOFF]
HCUTOFF_VALUE
# Out:
#                  Employee Name               Primary Job Title  \
# 25            Ellinger, Paul N                            PROF
# 35              Irwin, Scott H                            PROF
# 39               Khanna, Madhu                            PROF
# 43             Low, Sarah Anne                            PROF
# 53          Robe, Michel Andre                            PROF
# ...                        ...                             ...
# 6083         Khanna, Pradeep K        EXEC ASSOC VC CR ECO DEV
# 6112         Richardson, David  EXEC ASSOC VCRI/DIR SECRTY MGT
# 6164  Billhymer, Audrey Claire                  CLIN ASST PROF
# 6169        Constable, Peter D                            DEAN
# 6284           Garrick, Sean C     VC FOR DVSTY, EQUITY & INCL
#
#                     Department Name College Code  \
# 25         Agr & Consumer Economics           KL
# 35         Agr & Consumer Economics           KL
# 39         Agr & Consumer Economics           KL
# 43         Agr & Consumer Economics           KL
# 53         Agr & Consumer Economics           KL
# ...                             ...          ...
# 6083  Office of Corporate Relations           NE
# 6112       Sponsored Programs Admin           NE
# 6164   Veterinary Teaching Hospital           LC
# 6169    Vet Medicine Administration           LC
# 6284  Vice Chancellor for Diversity           NV
#
#                         College Name  Present FTE  Proposed FTE  \
# 25      Agr, Consumer & Env Sciences          1.0           1.0
# 35      Agr, Consumer & Env Sciences          1.0           1.0
# 39      Agr, Consumer & Env Sciences          1.0           1.0
# 43      Agr, Consumer & Env Sciences          1.0           1.0
# 53      Agr, Consumer & Env Sciences          1.0           1.0
# ...                              ...          ...           ...
# 6083  VC for Research and Innovation          1.0           1.0
# 6112  VC for Research and Innovation          1.0           1.0
# 6164             Veterinary Medicine          1.0           1.0
# 6169             Veterinary Medicine          1.0           1.0
# 6284   Vice Chancellor for Diversity          1.0           1.0
#
#       Present Salary  Proposed Salary Tenure Empl Class  \
# 25         440000.00        464200.01      A         AA
# 35         239241.47        248011.13      A         AA
# 39         295327.26        307093.62      A         AA
# 43         215000.00        223550.00      A         AA
# 53         244446.95        244446.95      A         AA
# ...              ...              ...    ...        ...
# 6083       261091.04        270765.04    NaN         BA
# 6112       292489.36        307113.83    NaN         BA
# 6164       230583.00        239806.32    NaN         AL
# 6169       366450.00        382940.25    NaN         BA
# 6284       351778.94        364091.20    NaN         BA
#
#                                    Secondary Job Titles  \
# 25                                                  NaN
# 35                       ['LJ NORTON CHAIR IN AG MKTG']
# 39    ['ACES DIST PROF-ENVIR ECON', 'DIR, ISEE', 'PR...
# 43                                             ['HEAD']
# 53    ['DIR OF GRAD PLACEMENT', 'TCC FOUND ENDOW PROF']
# ...                                                 ...
# 6083                                                NaN
# 6112                                                NaN
# 6164                                                NaN
# 6169                                           ['PROF']
# 6284                                                NaN
#
#                              Secondary Department Names
# 25                                                  NaN
# 35                   ['Latin American & Carib Studies']
# 39    ['Natural Res & Env Sci', 'Nutritional Science...
# 43                                                  NaN
# 53                            ['European Union Center']
# ...                                                 ...
# 6083                                                NaN
# 6112                                                NaN
# 6164                          ['Vet Clinical Medicine']
# 6169                          ['Vet Clinical Medicine']
# 6284                                                NaN
#
# [304 rows x 13 columns]

# %%
# Use this cell to create df_without_outliers
df_without_outliers= df[(df["Present Salary"] >= (Q1.item() - 1.5 * IQR)) &(df["Present Salary"] <= (Q3.item() + 1.5 * IQR))]

df_without_outliers
# Out:
#                   Employee Name              Primary Job Title  \
# 0         Gerstenecker, David G            DIR OF INFO TECHNOL
# 1           Henry, Joshua Keith         ASSOC DIR INFO TECHNOL
# 2               Meyer, Donald L               SR NETWORK ANLYS
# 3         Winter-Nelson, Alex E                           PROF
# 4     Axtman-Barker, Pamela Ann                          INSTR
# ...                         ...                            ...
# 6282   Abdullah-Span, Kaamilyah  DIR, CAMPUS CULTURE & CLIMATE
# 6283          Chambers, Sonya L    EXEC DIR STRATG INITIATIVES
# 6285     Guerra Perez, Gioconda        EXEC ASSOC VC FOR DVSTY
# 6286       VanDuyne, Adam Jareb            EXEC DIR FIN & ADMN
# 6287           Wantland, Ross A        DIR OF CURR DEVL & EDUC
#
#                     Department Name College Code  \
# 0          ACES Technology Services           KL
# 1          ACES Technology Services           KL
# 2          ACES Technology Services           KL
# 3          Agr & Consumer Economics           KL
# 4       Ag Ldrshp Educ Comm Program           KL
# ...                             ...          ...
# 6282  Vice Chancellor for Diversity           NV
# 6283  Vice Chancellor for Diversity           NV
# 6285  Vice Chancellor for Diversity           NV
# 6286  Vice Chancellor for Diversity           NV
# 6287  Vice Chancellor for Diversity           NV
#
#                        College Name  Present FTE  Proposed FTE  \
# 0      Agr, Consumer & Env Sciences          1.0           1.0
# 1      Agr, Consumer & Env Sciences          1.0           1.0
# 2      Agr, Consumer & Env Sciences          1.0           1.0
# 3      Agr, Consumer & Env Sciences          1.0           1.0
# 4      Agr, Consumer & Env Sciences          1.0           1.0
# ...                             ...          ...           ...
# 6282  Vice Chancellor for Diversity          1.0           1.0
# 6283  Vice Chancellor for Diversity          1.0           1.0
# 6285  Vice Chancellor for Diversity          1.0           1.0
# 6286  Vice Chancellor for Diversity          1.0           1.0
# 6287  Vice Chancellor for Diversity          1.0           1.0
#
#       Present Salary  Proposed Salary Tenure Empl Class  \
# 0          109670.28        112412.04    NaN         BA
# 1           83701.83         88723.94    NaN         BA
# 2           92692.76         96400.47    NaN         BA
# 3          193532.64        204244.60      A         AA
# 4           75000.00         75000.00    NaN         AL
# ...              ...              ...    ...        ...
# 6282       124062.50        127944.93    NaN         BA
# 6283       169500.00        176280.00    NaN         BA
# 6285       187250.00        195676.25    NaN         BA
# 6286       147200.00        153824.00    NaN         BA
# 6287        98860.00        102814.40    NaN         BA
#
#                              Secondary Job Titles  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3     ['DIR, ADMI', 'ASSOC DEAN FOR INATL PRGMS']
# 4                                             NaN
# ...                                           ...
# 6282                         ['INTERIM DIR, AAD']
# 6283                                          NaN
# 6285                                          NaN
# 6286                                          NaN
# 6287                                          NaN
#
#                              Secondary Department Names
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     ['ADM Institute for PHL', 'Agr, Consumer & Env...
# 4                                                   NaN
# ...                                                 ...
# 6282                                                NaN
# 6283                                                NaN
# 6285                                                NaN
# 6286                                                NaN
# 6287                                                NaN
#
# [5984 rows x 13 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for filtering the data to include non-outliers ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_without_outliers' in vars()), "Load the dataset into the variable named `df_without_outliers`."
assert ( len(df_without_outliers) == 5984 ), "You did not filter the dataset correctly."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 1.4: Boxplots (Round 2)
#
# Using `df_without_outliers`, create a boxplot of the `Present Salary` for the employees whose salary is not an outlier.

# %%
df_without_outliers.plot.box(column="Present Salary",title="Boxplot of Present Salary (Outliers Removed)", ylabel="Present Salary",xlabel="Employees")
# Out:
# <Axes: title={'center': 'Boxplot of Present Salary (Outliers Removed)'}, xlabel='Employees', ylabel='Present Salary'>

# %% [markdown]
# Note: You can see that the boxplot created above still has outliers. This is because the boxplot is created from the new DataFrame `df_without_outliers` rather than the original DataFrame `df`, calculating new outliers from our `df_without_outliers` data.

# %% [markdown]
# ### Part 1.5: Histograms (Round 2)

# %% [markdown]
# Using `df_without_outliers`, create a histogram of the `Present Salary` for the employees whose salary is not an outlier.

# %%
df_without_outliers.plot.hist(column="Present Salary",
    title="Histogram of Present Salary (Outliers Removed)",
    xlabel="Present Salary",
    ylabel="Number of Employees")
# Out:
# <Axes: title={'center': 'Histogram of Present Salary (Outliers Removed)'}, xlabel='Present Salary', ylabel='Number of Employees'>

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Department-Level Data
#
# Our Graybook dataset also includes the `Department Name` of each employee. This means you can see what department each professor is from and look at other employees in the same department.
#
# We can calculate **descriptive statistics** and look at visual displays of data on a **department level**!  Let’s explore whether or not there are salary **discrepancies** among departments.
#
# ### Part 2.1: Grouping the Data
#
# In lecture, you learned syntax that will help you **group** all of the people in each department so you can find departmental aggregates.  In other words, we want to group by `'Department Name'`.
#
# To make things easier to read, we will first modify your DataFrame to include only the `Department Name` and `Present Salary` fields before you `groupby`.
#
# First, using the cell below, create a second DataFrame named `depts` **containing only** the `Department Name` and `Present Salary` columns. Remember to use **double square-brackets** to specify these columns. Here's an example of the syntax: `df[['col1', 'col2']]`.
# - Make sure to use `df` that contains ALL employees.

# %%
depts = df[["Department Name", "Present Salary"]]
depts
# Out:
#                     Department Name  Present Salary
# 0          ACES Technology Services       109670.28
# 1          ACES Technology Services        83701.83
# 2          ACES Technology Services        92692.76
# 3          Agr & Consumer Economics       193532.64
# 4       Ag Ldrshp Educ Comm Program        75000.00
# ...                             ...             ...
# 6283  Vice Chancellor for Diversity       169500.00
# 6284  Vice Chancellor for Diversity       351778.94
# 6285  Vice Chancellor for Diversity       187250.00
# 6286  Vice Chancellor for Diversity       147200.00
# 6287  Vice Chancellor for Diversity        98860.00
#
# [6288 rows x 2 columns]

# %% [markdown]
# Now, find the mean Present Salary for each department to create `agg_mean_df`:

# %%
agg_mean_df = depts.groupby("Department Name").agg('mean').reset_index()
agg_mean_df
# Out:
#                     Department Name  Present Salary
# 0          ACES Technology Services    95354.956667
# 1    Academy Entrepreneurial Ldrshp    70106.250000
# 2                       Accountancy   203306.539167
# 3                       Advertising   110357.368571
# 4             Aerospace Engineering   128730.730909
# ..                              ...             ...
# 253       Veterinary Diagnostic Lab    92295.783500
# 254    Veterinary Teaching Hospital   135407.375882
# 255   Vice Chancellor for Diversity   179775.240000
# 256                    Web Services   138365.430000
# 257   Willard Airport Commercial Op   120277.750000
#
# [258 rows x 2 columns]

# %% [markdown]
# Hint: Remember to `reset_index()`

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert ( len(depts.columns) == 2 ), "Make sure your depts contains only the Department Name and Present Salary columns."
assert ( len(agg_mean_df.columns) == 2), "Make sure your agg_mean_df contains only the Department Name and Present Salary columns."
assert ("agg_mean_df" in vars()), "Make sure your aggregated DataFrame of means is named 'agg_mean_df'."
assert( len(agg_mean_df) == 258 ), "You should have 258 different departments.  Check to make sure you've grouped the data correctly."
assert( "Present Salary" in agg_mean_df ), "Your agg_mean_df is missing the Salary column."
assert( math.isclose(agg_mean_df['Present Salary'].mean(), 103214.15081569373 ) ), "Your salary values are incorrect. Double-check that you are aggregating by `mean`."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 2.2: Department Comparisons
#
# Let’s look at how the mean salaries differ across departments.
#
# Using your `agg_mean_df`, create a barplot for the departments with the top-40 average salaries. Make sure to change the figsize so that the plot looks better and that your x-axis is labeled appropriately.

# %%
top40 = agg_mean_df.sort_values("Present Salary").head(40)
top40
top40.plot.bar(x="Department Name",
    y="Present Salary",
    title="Top 40 Departments by Average Present Salary",
    xlabel="Department Name",
    ylabel="Average Present Salary")
# Out:
# <Axes: title={'center': 'Top 40 Departments by Average Present Salary'}, xlabel='Department Name', ylabel='Average Present Salary'>

# %% [markdown]
# ### Part 2.3: Grouping the Data, Again
#
# We have an aggregated DataFrame of the salaries by department, but what if we want to find the number of employees in each department?
#
# Each row represents a single employee, we can use this to find the number of employees per department. In the cell below, using your `depts` from earlier, create `agg_count_df` which finds the number of employees in each department:

# %%
agg_count_df = depts.groupby("Department Name")["Present Salary"].count().reset_index()
agg_count_df
# Out:
#                     Department Name  Present Salary
# 0          ACES Technology Services               3
# 1    Academy Entrepreneurial Ldrshp               2
# 2                       Accountancy              72
# 3                       Advertising              21
# 4             Aerospace Engineering              33
# ..                              ...             ...
# 253       Veterinary Diagnostic Lab              40
# 254    Veterinary Teaching Hospital              17
# 255   Vice Chancellor for Diversity               6
# 256                    Web Services               2
# 257   Willard Airport Commercial Op               2
#
# [258 rows x 2 columns]

# %% [markdown]
# If done correctly, your `agg_count_df` should now contain the number of employees in each department under the `Present Salary` column. But this column name is **misleading**.
#
# **Run the provided cell below** to rename the `Present Salary` column to `Num Employees`:

# %%
agg_count_df = agg_count_df.rename(columns={"Present Salary" : "Num Employees"})
agg_count_df
# Out:
#                     Department Name  Num Employees
# 0          ACES Technology Services              3
# 1    Academy Entrepreneurial Ldrshp              2
# 2                       Accountancy             72
# 3                       Advertising             21
# 4             Aerospace Engineering             33
# ..                              ...            ...
# 253       Veterinary Diagnostic Lab             40
# 254    Veterinary Teaching Hospital             17
# 255   Vice Chancellor for Diversity              6
# 256                    Web Services              2
# 257   Willard Airport Commercial Op              2
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Part 2.4: Departments With The Most Employees!
#
# Use the cell below to find the 10 departments that have the most employees.

# %%
agg_count_df.nlargest (10, "Num Employees")
# Out:
#                  Department Name  Num Employees
# 57         Cooperative Extension            244
# 144    Intercollegiate Athletics            207
# 51             Clinical Sciences            191
# 215        School of Social Work            175
# 116    IL Natural History Survey            172
# 235  Supercomputing Applications            170
# 56              Computer Science            131
# 80     Electrical & Computer Eng            112
# 85                       English             99
# 118   IL State Geological Survey             99

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert ( len(agg_count_df.columns) == 2 ), "Make sure your depts contains only the 2 columns."
assert ("agg_count_df" in vars()), "Make sure your aggregated DataFrame of employee counts is named 'agg_count_df'."
assert( len(agg_count_df) == 258 ), "You should have 258 different departments.  Check to make sure you've grouped the data correctly."
assert( "Num Employees" in agg_count_df ), "Your agg_count_df is missing the Num Employees column. Make sure you ran the provided cell to rename the column."
assert( math.isclose( agg_count_df['Num Employees'].mean(), 24.372093023255815 ) ), "Your employee counts are incorrect. Double-check that you are aggregating by `count`."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 2.5: Salaries and Number of Employees
#
# To visualize the relationship between the Departments' number of employees and their average salaries, we are going to create a scatter plot. In order to create the scatter plot, we need to use the appropriate columns from `agg_mean_df` and `agg_count_df`:
#
# In the DataFrame `agg_count_df`, create a new column called "Average Salary" which contains the average salary for each department. (Remember: You have already calculated the average salary for each department in `agg_mean_df`. You can use that column)
#
# Then create a scatterplot using x = "Num Employees" and y = "Average Salary". Make sure you add a title to your scatterplot!

# %%
# Create a new column in agg_count_df
agg_count_df ["Average Salary"]= agg_mean_df ['Present Salary']
agg_count_df
# Out:
#                     Department Name  Num Employees  Average Salary
# 0          ACES Technology Services              3    95354.956667
# 1    Academy Entrepreneurial Ldrshp              2    70106.250000
# 2                       Accountancy             72   203306.539167
# 3                       Advertising             21   110357.368571
# 4             Aerospace Engineering             33   128730.730909
# ..                              ...            ...             ...
# 253       Veterinary Diagnostic Lab             40    92295.783500
# 254    Veterinary Teaching Hospital             17   135407.375882
# 255   Vice Chancellor for Diversity              6   179775.240000
# 256                    Web Services              2   138365.430000
# 257   Willard Airport Commercial Op              2   120277.750000
#
# [258 rows x 3 columns]

# %%
# Create your scatterplot
agg_count_df.plot.scatter(x="Num Employees",y="Average Salary",title="Department Size vs. Average Salary")
# Out:
# <Axes: title={'center': 'Department Size vs. Average Salary'}, xlabel='Num Employees', ylabel='Average Salary'>

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 3: Gender and Salaries
#
# Data can often reveal **systemic problems or discrimination**. For example, in many companies, men and women are promoted at **different rates**.  Let’s look at a subset of the salary dataset to investigate whether or not there is a **difference in salaries** between faculty who identify as men and women in two departments: **STAT** and **CS** (Karle and Wade’s home departments).
#
# We've compiled data from these departments, added a `Gender` column, and placed it in a dataset called `STAT_CS_gender.csv`.
#
# This data is also located in the **same directory as this lab**. To load it in, just specify the **local file path** (`"STAT_CS_gender.csv"`)!

# %% [markdown]
# ### Part 3.1: Loading Our Dataset
# Using the cell below, read `STAT_CS_gender.csv`, store it in a variable called `STAT_CS_df`, and display it to see what it looks like!

# %%
import pandas as pd
STAT_CS_df = pd.read_csv("STAT_CS_gender.csv")
STAT_CS_df
# Out:
#                     Employee Name Gender Primary Job Title   Department Name  \
# 0               Abdelzaher, Tarek      M              PROF  Computer Science
# 1                  Adve, Sarita V      F              PROF  Computer Science
# 2           Adve, Vikram Sadanand      M              PROF  Computer Science
# 3           Alagappan, Ramnatthan      M         ASST PROF  Computer Science
# 4    Alawini, Abdussalam Alhadi M      M    TCH ASSOC PROF  Computer Science
# ..                            ...    ...               ...               ...
# 140               Zhang, Lingming      M        ASSOC PROF  Computer Science
# 141                     Zhao, Han      M         ASST PROF  Computer Science
# 142              Zhao, Sihai Dave      M        ASSOC PROF        Statistics
# 143                  Zhu, Ruoqing      M        ASSOC PROF        Statistics
# 144                 Zilles, Craig      M              PROF  Computer Science
#
#     College Code             College Name  Present FTE  Proposed FTE  \
# 0             KP     Grainger Engineering          1.0           1.0
# 1             KP     Grainger Engineering          1.0           1.0
# 2             KP     Grainger Engineering          1.0           1.0
# 3             KP     Grainger Engineering          1.0           1.0
# 4             KP     Grainger Engineering          1.0           1.0
# ..           ...                      ...          ...           ...
# 140           KP     Grainger Engineering          1.0           1.0
# 141           KP     Grainger Engineering          1.0           1.0
# 142           KV  Liberal Arts & Sciences          1.0           1.0
# 143           KV  Liberal Arts & Sciences          1.0           1.0
# 144           KP     Grainger Engineering          1.0           1.0
#
#      Present Salary  Proposed Salary Tenure Empl Class  \
# 0         220000.00        228800.00      A         AA
# 1         230000.00        240000.00      A         AA
# 2         230000.00        240000.00      A         AA
# 3         135000.00        140400.00      P         AA
# 4         138000.00        153600.00      M         AA
# ..              ...              ...    ...        ...
# 140       155000.00        163200.00      A         AA
# 141       136000.00        141440.00      P         AA
# 142       135475.46        141247.33      A         AA
# 143       117159.38        125845.76      A         AA
# 144       185000.00        192400.00      A         AA
#
#                                   Secondary Job Titles  \
# 0                           ['PROF, CSL', 'PROF, ITI']
# 1                           ['PROF, CSL', 'PROF, ITI']
# 2             ['PROF, CSL', 'PROF, ITI', 'PROF, NCSA']
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142  ['ASSOC PROF, CI MED', 'AFFILIATE, IGB', 'ASST...
# 143  ['ASSOC PROF, CI MED', 'AFFILIATE, IGB', 'ASSO...
# 144                            ['SEVERNS FAC SCHOLAR']
#
#                             Secondary Department Names
# 0    ['Coordinated Science Lab', 'Information Trust...
# 1    ['Coordinated Science Lab', 'Electrical & Comp...
# 2    ['Coordinated Science Lab', 'Information Trust...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                      ['Electrical & Computer Eng']
# 142  ['Biomed & Translational Sci', 'Bioengineering...
# 143  ['Biomed & Translational Sci', 'Institute for ...
# 144                                                NaN
#
# [145 rows x 14 columns]

# %% [markdown]
# Now, let's create **two subsets** of our `STAT_CS_df`.
#
# Using conditionals in the cells below, create:
# - `STAT_CS_M`, a `DataFrame` of the staff and faculty who identify as Male (**"M"**) under the `Gender` column
# - `STAT_CS_F`, a `DataFrame` of the staff and faculty who identified as Female (**"F"**) under the `Gender` column

# %%
STAT_CS_M = STAT_CS_df[STAT_CS_df["Gender"] == "M"]
STAT_CS_M
# Out:
#                      Employee Name Gender Primary Job Title   Department Name  \
# 0                Abdelzaher, Tarek      M              PROF  Computer Science
# 2            Adve, Vikram Sadanand      M              PROF  Computer Science
# 3            Alagappan, Ramnatthan      M         ASST PROF  Computer Science
# 4     Alawini, Abdussalam Alhadi M      M    TCH ASSOC PROF  Computer Science
# 6    Angrave, Lawrence Christopher      M          TCH PROF  Computer Science
# ..                             ...    ...               ...               ...
# 140                Zhang, Lingming      M        ASSOC PROF  Computer Science
# 141                      Zhao, Han      M         ASST PROF  Computer Science
# 142               Zhao, Sihai Dave      M        ASSOC PROF        Statistics
# 143                   Zhu, Ruoqing      M        ASSOC PROF        Statistics
# 144                  Zilles, Craig      M              PROF  Computer Science
#
#     College Code             College Name  Present FTE  Proposed FTE  \
# 0             KP     Grainger Engineering          1.0           1.0
# 2             KP     Grainger Engineering          1.0           1.0
# 3             KP     Grainger Engineering          1.0           1.0
# 4             KP     Grainger Engineering          1.0           1.0
# 6             KP     Grainger Engineering          1.0           1.0
# ..           ...                      ...          ...           ...
# 140           KP     Grainger Engineering          1.0           1.0
# 141           KP     Grainger Engineering          1.0           1.0
# 142           KV  Liberal Arts & Sciences          1.0           1.0
# 143           KV  Liberal Arts & Sciences          1.0           1.0
# 144           KP     Grainger Engineering          1.0           1.0
#
#      Present Salary  Proposed Salary Tenure Empl Class  \
# 0         220000.00        228800.00      A         AA
# 2         230000.00        240000.00      A         AA
# 3         135000.00        140400.00      P         AA
# 4         138000.00        153600.00      M         AA
# 6         160000.00        171000.00      M         AA
# ..              ...              ...    ...        ...
# 140       155000.00        163200.00      A         AA
# 141       136000.00        141440.00      P         AA
# 142       135475.46        141247.33      A         AA
# 143       117159.38        125845.76      A         AA
# 144       185000.00        192400.00      A         AA
#
#                                   Secondary Job Titles  \
# 0                           ['PROF, CSL', 'PROF, ITI']
# 2             ['PROF, CSL', 'PROF, ITI', 'PROF, NCSA']
# 3                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142  ['ASSOC PROF, CI MED', 'AFFILIATE, IGB', 'ASST...
# 143  ['ASSOC PROF, CI MED', 'AFFILIATE, IGB', 'ASSO...
# 144                            ['SEVERNS FAC SCHOLAR']
#
#                             Secondary Department Names
# 0    ['Coordinated Science Lab', 'Information Trust...
# 2    ['Coordinated Science Lab', 'Information Trust...
# 3                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                      ['Electrical & Computer Eng']
# 142  ['Biomed & Translational Sci', 'Bioengineering...
# 143  ['Biomed & Translational Sci', 'Institute for ...
# 144                                                NaN
#
# [106 rows x 14 columns]

# %%
STAT_CS_F = STAT_CS_df[STAT_CS_df["Gender"] == "F"]
STAT_CS_F
# Out:
#                     Employee Name Gender Primary Job Title   Department Name  \
# 1                  Adve, Sarita V      F              PROF  Computer Science
# 5              Amato, Nancy Marie      F              PROF  Computer Science
# 10         Bravo De Guenni, Lelys      F   CLIN ASSOC PROF        Statistics
# 19        Chronopoulou, Alexandra      F   CLIN ASSOC PROF        Statistics
# 21           Cobb, Camille Morgan      F         ASST PROF  Computer Science
# 24      Cunningham, Kathryn Irene      F         ASST PROF  Computer Science
# 27               Dayanikli, Gokce      F         ASST PROF        Statistics
# 28                 Deeke, Julie M      F     TCH ASST PROF        Statistics
# 34        Ellison, Victoria Marie      F     TCH ASST PROF        Statistics
# 41            Flanagan, Karle Ann      F    TCH ASSOC PROF        Statistics
# 42              Fleck, Margaret M      F     TEACHING PROF  Computer Science
# 46             Ganesan, Aishwarya      F         ASST PROF  Computer Science
# 47                  Gertner, Yael      F     TCH ASST PROF  Computer Science
# 52                  Gui, Liangyan      F     RES ASST PROF  Computer Science
# 54                   Gunter, Elsa      F       SR LECTURER  Computer Science
# 62   Hockenmaier, Julia Constanze      F              PROF  Computer Science
# 64   Jabbarvand Behrouz, Reyhaneh      F         ASST PROF  Computer Science
# 66                       Ji, Heng      F              PROF  Computer Science
# 68     Karahalios, Kyratso George      F              PROF  Computer Science
# 69              Khurana, Dakshita      F         ASST PROF  Computer Science
# 72         Kravets, Robin Hillary      F              PROF  Computer Science
# 73                Kumar, Ranjitha      F        ASSOC PROF  Computer Science
# 75             Lazebnik, Svetlana      F              PROF  Computer Science
# 77           Lewis, Colleen Marie      F        ASSOC PROF  Computer Science
# 78                         Li, Bo      F         ASST PROF  Computer Science
# 79                         Li, Bo      F              PROF        Statistics
# 80                    Liang, Feng      F              PROF        Statistics
# 81                    Liu, Hongye      F     TCH ASST PROF  Computer Science
# 84                    Mehta, Ruta      F        ASSOC PROF  Computer Science
# 89               Nahrstedt, Klara      F              PROF  Computer Science
# 101            Ringer, Talia Lily      F         ASST PROF  Computer Science
# 103                  Schatz, Jule      F     TCH ASST PROF  Computer Science
# 107       Silva, Mariana Teixeira      F    TCH ASSOC PROF  Computer Science
# 114  Soltanaghaei Koupaei, Elaheh      F         ASST PROF  Computer Science
# 116        Sterman, Sarah Gimbert      F     RES ASST PROF  Computer Science
# 119                 Tahboub, Ruby      F     TCH ASST PROF  Computer Science
# 128        Wang, Michelle Yongmei      F        ASSOC PROF        Statistics
# 132                 Warnow, Tandy      F              PROF  Computer Science
# 133           Williams, Tiffani L      F          TCH PROF  Computer Science
#
#     College Code             College Name  Present FTE  Proposed FTE  \
# 1             KP     Grainger Engineering          1.0           1.0
# 5             KP     Grainger Engineering          1.0           1.0
# 10            KV  Liberal Arts & Sciences          1.0           1.0
# 19            KV  Liberal Arts & Sciences          1.0           1.0
# 21            KP     Grainger Engineering          1.0           1.0
# 24            KP     Grainger Engineering          1.0           1.0
# 27            KV  Liberal Arts & Sciences          1.0           1.0
# 28            KV  Liberal Arts & Sciences          1.0           1.0
# 34            KV  Liberal Arts & Sciences          1.0           1.0
# 41            KV  Liberal Arts & Sciences          1.0           1.0
# 42            KP     Grainger Engineering          1.0           1.0
# 46            KP     Grainger Engineering          1.0           1.0
# 47            KP     Grainger Engineering          1.0           1.0
# 52            KP     Grainger Engineering          1.0           1.0
# 54            KP     Grainger Engineering          1.0           1.0
# 62            KP     Grainger Engineering          1.0           1.0
# 64            KP     Grainger Engineering          1.0           1.0
# 66            KP     Grainger Engineering          1.0           1.0
# 68            KP     Grainger Engineering          1.0           1.0
# 69            KP     Grainger Engineering          1.0           1.0
# 72            KP     Grainger Engineering          1.0           1.0
# 73            KP     Grainger Engineering          1.0           1.0
# 75            KP     Grainger Engineering          1.0           1.0
# 77            KP     Grainger Engineering          1.0           1.0
# 78            KP     Grainger Engineering          1.0           1.0
# 79            KV  Liberal Arts & Sciences          1.0           1.0
# 80            KV  Liberal Arts & Sciences          1.0           1.0
# 81            KP     Grainger Engineering          1.0           1.0
# 84            KP     Grainger Engineering          1.0           1.0
# 89            KP     Grainger Engineering          1.0           1.0
# 101           KP     Grainger Engineering          1.0           1.0
# 103           KP     Grainger Engineering          1.0           1.0
# 107           KP     Grainger Engineering          1.0           1.0
# 114           KP     Grainger Engineering          1.0           1.0
# 116           KP     Grainger Engineering          1.0           1.0
# 119           KP     Grainger Engineering          1.0           1.0
# 128           KV  Liberal Arts & Sciences          1.0           1.0
# 132           KP     Grainger Engineering          1.0           1.0
# 133           KP     Grainger Engineering          1.0           1.0
#
#      Present Salary  Proposed Salary Tenure Empl Class  \
# 1         230000.00        240000.00      A         AA
# 5         293100.00        309775.00      A         AA
# 10        100000.00        105000.00    NaN         AA
# 19        105570.00        109792.80    NaN         AA
# 21        136000.00        141440.00      P         AA
# 24        135000.00        140400.00      P         AA
# 27        118000.00        118000.00      P         AA
# 28         90045.00         93646.80    NaN         AA
# 34         90134.50         93739.88    NaN         AA
# 41        104000.00        115760.00    NaN         AA
# 42        165000.00        175526.00      M         AA
# 46        135000.00        140400.00      P         AA
# 47        137000.00        142480.00      M         AA
# 52        137000.00        142480.00      M         AA
# 54        170000.00        178000.00      M         AA
# 62        195000.00        203280.00      A         AA
# 64        137000.00        142480.00      P         AA
# 66        207500.00        217875.00      A         AA
# 68        207500.00        215800.00      A         AA
# 69        138000.00        143520.00      P         AA
# 72        202500.00        210300.00      A         AA
# 73        157000.00        165280.00      A         AA
# 75        195000.00        202800.00      A         AA
# 77        155000.00        163200.00      A         AA
# 78        140000.00        145600.00      P         AA
# 79        179757.53        192472.18      A         AA
# 80        155409.36        161625.73      A         AA
# 81        137000.00        142480.00      M         AA
# 84        140000.00        155875.00      A         AA
# 89        285000.00        295800.00      A         AA
# 101       136000.00        141440.00      P         AA
# 103       135000.00        135000.00    NaN         AA
# 107       152000.00        158080.00    NaN         AA
# 114       136000.00        141440.00      P         AA
# 116       135000.00        140400.00      M         AA
# 119       135000.00        140400.00      M         AA
# 128        89535.25         89535.25      A         AA
# 132       282500.00        293125.00      A         AA
# 133       177500.00        185500.00      M         AA
#
#                                   Secondary Job Titles  \
# 1                           ['PROF, CSL', 'PROF, ITI']
# 5    ['HEAD', 'PROF, CSL', 'PROF, HCESC', 'AFFILIAT...
# 10                                                 NaN
# 19                                  ['CSBS AFFILIATE']
# 21                                                 NaN
# 24                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 34                                                 NaN
# 41                          ['DIR INCLSV DATA SCI ED']
# 42                                  ['RES ASSOC PROF']
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 54                       ['RES PROF', 'RES PROF, ITI']
# 62                                       ['PROF, CSL']
# 64                                                 NaN
# 66                                       ['PROF, CSL']
# 68            ['PROF, CSL', 'PROF, ITI', 'PROF, NCSA']
# 69                                                 NaN
# 72     ['DIR OF GRAD PRGMS', 'PROF, CSL', 'PROF, ITI']
# 73                                                 NaN
# 75                                                 NaN
# 77                                                 NaN
# 78                                  ['ASST PROF, ITI']
# 79                  ['CHAIR STATISTICS', 'PROF, NCSA']
# 80                                       ['PROF, ITI']
# 81                                                 NaN
# 84                                                 NaN
# 89   ['PROF, CI MED', 'DIR, CSL', 'PROF, CSL', 'PRO...
# 101                                                NaN
# 103                                                NaN
# 107                                                NaN
# 114              ['ASST PROF, CSL', 'ASST PROF, NCSA']
# 116                                                NaN
# 119                                                NaN
# 128                       ['ASSOC PROF, BECKMAN INST']
# 132  ['ASSOC HEAD', 'PROF, CSL', 'DEPT AFFL', 'PROF...
# 133                            ['DIR OF ONRAMP PRGMS']
#
#                             Secondary Department Names
# 1    ['Coordinated Science Lab', 'Electrical & Comp...
# 5    ['Coordinated Science Lab', 'Institute for Gen...
# 10                  ['Latin American & Carib Studies']
# 19   ['Coordinated Science Lab', 'Interdis Health S...
# 21                                                 NaN
# 24                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 34                                                 NaN
# 41                              ['LAS Administration']
# 42                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 54                     ['Information Trust Institute']
# 62          ['Coordinated Science Lab', 'Linguistics']
# 64                                                 NaN
# 66                         ['Coordinated Science Lab']
# 68   ['Coordinated Science Lab', 'Electrical & Comp...
# 69                                                 NaN
# 72   ['Coordinated Science Lab', 'Electrical & Comp...
# 73                       ['Electrical & Computer Eng']
# 75                       ['Electrical & Computer Eng']
# 77                                                 NaN
# 78   ['Electrical & Computer Eng', 'Information Tru...
# 79                     ['Supercomputing Applications']
# 80                     ['Information Trust Institute']
# 81                                                 NaN
# 84                                                 NaN
# 89   ['Biomed & Translational Sci', 'Coordinated Sc...
# 101                                                NaN
# 103                                                NaN
# 107                                  ['Lemann Center']
# 114  ['Coordinated Science Lab', 'Electrical & Comp...
# 116                                                NaN
# 119                                                NaN
# 128  ['Bioengineering', 'Center for Global Studies'...
# 132  ['Bioengineering', 'Coordinated Science Lab', ...
# 133                                                NaN

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("STAT_CS_df" in vars()), "Ensure you've named your original DataFrame `STAT_CS_df`."
assert(len(STAT_CS_df) == 145), "This is not the STAT_CS_df you are looking for."
assert("STAT_CS_M" in vars()), "Ensure your male subset of STAT_CS_df is named `STAT_CS_M`."
assert(len(STAT_CS_M) == 106), "Double check your conditional to generate STAT_CS_M - the number of rows is incorrect."
assert("STAT_CS_F" in vars()), "Ensure your female subset of STAT_CS_df is named `STAT_CS_F`."
assert(len(STAT_CS_F) == 39), "Double check your conditional to generate STAT_CS_F - the number of rows is incorrect."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 3.2: Merging Two Columns into One DataFrame
#
# To create a new DataFrame containing only the data you found above, the following provided line of code creates `df_salary_by_gender`:

# %%
df_salary_by_gender = pd.DataFrame({
    "female": STAT_CS_F["Present Salary"],
    "male": STAT_CS_M["Present Salary"],
})

# %% [markdown]
# Take a look at the DataFrame `df_salary_by_gender`.  Every row will either have data for in the `female` column or the `male` column:

# %%
df_salary_by_gender
# Out:
#        female       male
# 0         NaN  220000.00
# 1    230000.0        NaN
# 2         NaN  230000.00
# 3         NaN  135000.00
# 4         NaN  138000.00
# ..        ...        ...
# 140       NaN  155000.00
# 141       NaN  136000.00
# 142       NaN  135475.46
# 143       NaN  117159.38
# 144       NaN  185000.00
#
# [145 rows x 2 columns]

# %% [markdown]
# ### Part 3.3: Visualization
#
# Let's create a visualization! Using the next cell, create a **boxplot** of `df_salary_by_gender` that includes both genders:

# %%
df_salary_by_gender.plot.box(title="Boxplot of Salaries by Gender", ylabel="Present Salary")
# Out:
# <Axes: title={'center': 'Boxplot of Salaries by Gender'}, ylabel='Present Salary'>

# %% [markdown]
# ### Part 3.4: EDA, Again
#
# Now that we've visualized the data, let's explore some basic statistics once more to gain further insight.
#
# In the following cells, calculate:
# - The **mean** `Present Salary` for **Male** STAT/CS Faculty, storing in the variable `mean_m`
# - The **median** `Present Salary` for **Male** STAT/CS Faculty, storing in the variable `median_m`
# - The **standard deviation** of `Present Salary` for **Male** STAT/CS Faculty, storing in the variable `std_m`

# %%
# Calculate and display the mean
mean_m = STAT_CS_M["Present Salary"].mean()
mean_m.item()
# Out:
# 157679.5082075472

# %%
# Calculate and display the median
median_m = STAT_CS_M["Present Salary"].median()
median_m.item()
# Out:
# 152500.0

# %%
# Calculate and display the standard deviation
std_m = STAT_CS_M["Present Salary"].std()
std_m.item()
# Out:
# 49368.32738020144

# %% [markdown]
# Now, in the cells below, calculate:
#
# - The **mean** `Present Salary` for **Female** STAT/CS Faculty, storing in the variable `mean_f`
# - The **median** `Present Salary` for **Female** STAT/CS Faculty, storing in the variable `median_f`
# - The **standard deviation** of `Present Salary` for **Female** STAT/CS Faculty, storing in the variable `std_f`

# %%
# Calculate and display the mean
mean_f = STAT_CS_F["Present Salary"].mean()
mean_f.item()
# Out:
# 157847.47794871795

# %%
# Calculate and display the median
median_f = STAT_CS_F["Present Salary"].median()
median_f.item()
# Out:
# 138000.0

# %%
# Calculate and display the standard deviation
std_f = STAT_CS_F["Present Salary"].std()
std_f.item()
# Out:
# 50583.79948660857

# %% [markdown]
# Run the following cell to make a summary table of your previously calculated data:

# %%
pd.DataFrame([
  {"Gender": "F", "Mean ($)": round(mean_f), "Median ($)": round(median_f), "Standard Deviation ($)": round(std_f)},
  {"Gender": "M", "Mean ($)": round(mean_m), "Median ($)": round(median_m), "Standard Deviation ($)": round(std_m)},
])
# Out:
#   Gender  Mean ($)  Median ($)  Standard Deviation ($)
# 0      F    157847      138000                   50584
# 1      M    157680      152500                   49368

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 3.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( math.isclose( mean_f, 157847.477949 ) )
assert( math.isclose( median_f, 138000.0 ) )
assert( math.isclose( std_f, 50583.799487 ) )
assert( math.isclose( mean_m, 157679.508208 ) )
assert( math.isclose( median_m, 152500.0 ) )
assert( math.isclose( std_m, 49368.327380 ) )

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 4: Exploring Your Own Interests
#
#
# At this point of the lab, we have investigated a lot of questions.
#
# However, these have been questions that **we told you to answer**. As a data scientist, it is important to be able to use the data science skills that you learn in the classroom to answer questions that **you have**.
#
# Think about **two questions** that you have about the **Graybook** or **STAT_CS_Gender** datasets that have not been answered. These can be simple questions. Record them below.  Then, answer at least one of these questions using Python and either dataset.

# %% [markdown]
# *(✏️ Graybook dataset:
# “Which department has the most employees?”
#
#  STATCSgender dataset:
#
# "Do male or female faculty earn more on average in CS and STAT?✏️)*

# %% [markdown]
# Now, use the cell below to **find the answer** to **one** of your questions! Remember, it can be something simple.

# %%
On average, male faculty in both CS and STAT earn more than female faculty
# Out:
#   Cell In[426], line 1
#     On average, male faculty in both CS and STAT earn more than female faculty
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Analysis: lab_plots takeaways
#
# Please answer the following questions in complete sentences:

# %% [markdown]
# **Question 1:** In this lab, you explored two types of data visualizations: box plots and histograms. Explain why is it valuable to look at visual displays of salary data in general (as opposed to just looking at descriptive statistics like the mean and standard deviation)?
#
# **Question 2:** In Part 3, you calculated descriptive statistics of the `Present Salary` of Male and Female STAT/CS Faculty. Based on the work you did in this section, can we draw any conclusions about gender-based salary discrimination from our data? Use the analysis you did to support your answer.
#
# **Question 3:** What was the most interesting thing you learned from doing this lab?

# %% [markdown]
# *(✏️ Write your answers to the analysis here. Make sure to use complete sentences and be as descriptive as possible in your answers.✏️)*

# %%
1.The need to be able to create visual displays (e.g., boxplots or histograms) is useful because visual displays identify data patterns that can’t be established using the descriptive statistics. For example, calculating a mean or standard deviation is essentially summarizing with a single number (e.g., average salary). 
When using a histogram, you take the same data and show it represents the full distribution of salaries, if it’s skewed, going across the range or going into several select ranges. Boxplots similarly show outlier representations, median and interquartile ranges. 
Therefore, when looking at salaries in the lab, visual display of salaries gave first observations of inequity of salary differences (things that potentially can be hidden by means and standard deviation).

2. In Part 3, I describe mean, median, and standard deviation for men and women in the STAT and CS department. The analysis shows that for these departments men faculty make higher averages than women faculty. However, the data set is not universal (only two departments, not the entire university). 
Therefore, we observed gender salary disparity but it does not describe a gender salary inequity across the university. Other factors should be take into account like tenure, experience, rank, and other variables related to salary.

3. What’s most interesting to me from this lab is mixing visual displays and descriptive statistics to visualize real world situations like salary disparity by gender or department. 
It shows even small datasets could lead to significant equity questions / and systemic issues - and the power of data science could lead to equitable solutions in our systematic world.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Lab Submission
#
#
# You're almost done! All you need to do is to commit your lab to GitHub:
#
# 1. Make certain to save your work. To do this, go to **File => Save All**
#
# 2. After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
