# %% [markdown]
# # Welcome to lab_🐼s!
#
# Last week, you did amazing work setting up your computer for the rest of the semester! Now, let's use your computer to do data science for the first time!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant (TA), your Course Assistants (CAs), your lab group, and the professors (Prof. Karle and Prof. Wade), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 0: Your Lab Group!
#
# We find that it's best to program with a group of people so everyone can help each other out!
#
# - A key part of Data Science is being able to **communicate about the work you've done**. By learning strong communication skills, you will be able to **explain your code**, and the underlying data science concepts, to everyone -- data scientists and non-scientists alike!
#
# - **Every lab** you will need to complete some parts of the lab **with your group**. There will be both **"group discussion questions"** and **"individual written reflection questions"** as part of every lab.

# %% [markdown]
# ## Create Your Group
#
# If you have not done so already, **RIGHT NOW** find people to make a group of **two, three, or four** people (we find that groups of 3 are ideal).
#
# - If you're at a group of five, split into a group of two and a group of three. You can still help each other as a larger group, but the group questions should be answered in your smaller group of 2-4 people.
#
# Once you have your group, **introduce yourselves to each other! :)**

# %% [markdown]
# ## Record Your Group
#
# Since you know Python, edit the following cell to add strings about your group:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Hunnius2@Illinois.edu"
ca1_name = "Soph"
ca2_name = "Maddy"
ca3_name = ""


# As part of your introduction, learn your lab partner's name, major, and
# learn something new about them that you never knew!
partner1_name = "Savanna"
partner1_netid = "svinson2"
partner1_major = "RST Sports Managment"

partner2_name = ""
partner2_netid = ""
partner2_major = ""

partner3_name = ""
partner3_netid = ""
partner3_major = ""

# Which lab section are you in? Record it below! It should start with a Y and have 
# 2 numbers after the Y. If you're unsure - ask your TA/CAs!
lab_section = "Y01"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: 🧑‍🤝‍🧑 Hello Dataset!

# %% [markdown]
# In lecture, we have started to explore the "Party Words Dataset" that you created. We will continue to use the Party Words Dataset all semester long, but we want even more datasets -- and we want you to come up with the questions!
#
# In this lab, **you and your group members** will come up with questions to ask the entire class to create the **"Hello Dataset"**!

# %% [markdown]
# ## Hello Dataset Overview
#
# This upcoming weekend, your lab homework will be to fill out a class-wide "Hello Survey".  Right now, with your group, you will come up some of the questions that should be on this survey *(and you will do analysis on your questions next week!)*.
#
# With your group, come up with four questions below!  Before you get started, a few notes:
#
# - The survey will be **NOT be anonymous** and the results will be shared with the class to do analysis on, so you should **only ask questions you feel comfortable sharing with the class**.
# - **Questions that are inappropriate** for a classroom environment will be thrown out and you won't earn points for any question we throw out. (Keep everything at most PG/PG-13.)
# - You are going to submit **one set of questions for your whole group** and you must decide on the questions together.

# %% [markdown]
# ## Q1: Question with a Binary Response
#
# A question with a **binary response** is a question that has only two answers.  For example:
# - *Do you prefer cats or dogs?*
# - *Were you born in Illinois?*
#
# With your group, come up with one question that you think will have **exactly 50%/50%** split between the two binary outcomes.  *(The question that gets closest to 50%/50% will get extra credit!)*

# %% [markdown]
# **What is your binary question?**
#
# What computer do you have, microsoft or apple?

# %% [markdown]
# **Why do you think this is a good question?  Write at least two complete sentences on why you believe your question will have a 50%/50% split.**
#
# Every college student has a computer or a form of technology that is from one of these companies. Secondly, some students may need a more higher performing computer than others due to their major.

# %% [markdown]
# ## Q2: Question with a Numeric Response
#
# A question with a **numeric response** requires a number for an answer.  For example:
#
# - *What is your height in inches?*
# - *What day were you born?*
#
# With your group, come up with a single numeric response question. Also, include a prediction on what you think the most frequent answer will be to your question.

# %% [markdown]
# **What is your numeric question?**
#
# How long does it take you to get ready for the day?

# %% [markdown]
# **What do you think the most frequent answer will be?**
#
# 30 minutes

# %% [markdown]
# **Why do you think this answer will be the most frequent answer?  Write at least one complete sentence on why you believe that it will be the most frequent answer.**
#
# I believe that depending how early someone wakes up and what time they have class, the time that they get ready can vary. Some people will take longer than others

# %% [markdown]
# ## Q3: Question with a (non-numeric) Textual Response
#
# A question with a (non-numeric) **textual response** requires a word or two for an answer.  For example:
#
# - *What is your favorite sport to play?*
# - *What is the location of your favorite trip/vacation?*
#
# With your group, come up with a single textual response question where at least two members of your group share the same answer.

# %% [markdown]
# What is your favorite color?

# %% [markdown]
# **What is the shared answer between your group?  Do you also share this answer (if not, what's your answer to the question)?**
#
# We both like pink

# %% [markdown]
# ## Q4: Open Question
#
# One final question -- no restrictions on the format!  Is there a great question your group discussed that you did not get to use as one of the first three questions but you want to know the class's answer?

# %% [markdown]
# **What is your final question for the whole class?**
#
# What are you career goals after school?

# %% [markdown]
# ## Submit Your Questions to Professors Wade and Karle
#
# Your lab TAs will be grading your lab notebook for your full responses, but we want to make sure to get the survey with your questions out to everyone ASAP!
#
# - Pick one member of your group as the "question submitter".
# - If you're the question submitter, complete this Google Form for your group (requires @illinois.edu login): https://docs.google.com/forms/d/e/1FAIpQLSfQ0XKPQXwRXEtA9OKmO2Ty8_yVrcARIO1l8qk7merHGDhdQg/viewform?usp=sharing&ouid=103660412360957657789
# - Make sure to do this **during your lab section**.

# %% [markdown]
# ## This Weekend: Complete the "Hello Survey"
#
# On Friday evening, we will post the "Hello Survey" on Canvas with the questions you (and the entire class) asked.  You will have to complete this before **Monday, Sept. 8th** and it will be part of your lab grade.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Importing the Course Catalog Dataset
#
# In lecture, you learned that we will use the `pandas` **library** for working with data. Libraries are collections of functions and other objects that extend what Python can do by itself.  The `pandas` library is the most widely used library for data science.
#
# To use the `pandas` library, we must **import** it into your notebook.  In every lab, you will need to import the library just like we did in lecture!
#
# In the following cell, replace `...` with the code to import pandas as `pd`:

# %% [markdown]
# In lecture, you saw the "Course Catalog" dataset.  Using the `read_csv` function, load the course catalog dataset.  The URL for this dataset is:
# ```
# http://waf-server-01.cs.illinois.edu/static/course-catalog.csv
# ```
#
# Remember, URLs passed to `read_csv` are **string** variables, so remember to use **quotation marks**.
#
# > **macOS users**: If you are running macOS, you may get a HTTPS connection security-related error.  If you get this error, there's a solution for you on the Canvas lab overview page!! :)

# %%
# Load the course catalog dataset into a variable named `df`:
import pandas as pd

# %%
# Look at `df` to confirm that this worked:
df= pd.read_csv("http://waf-server-01.cs.illinois.edu/static/course-catalog.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2025  Spring  2025-sp     AAS     100  Intro Asian American Studies
# 1      2025  Spring  2025-sp     AAS     100  Intro Asian American Studies
# 2      2025  Spring  2025-sp     AAS     100  Intro Asian American Studies
# 3      2025  Spring  2025-sp     AAS     100  Intro Asian American Studies
# 4      2025  Spring  2025-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 12316  2025  Spring  2025-sp    WRIT     303          Writing Across Media
# 12317  2025  Spring  2025-sp    WRIT     303          Writing Across Media
# 12318  2025  Spring  2025-sp    YDSH     102          Beginning Yiddish II
# 12319  2025  Spring  2025-sp    YDSH     102          Beginning Yiddish II
# 12320  2025  Spring  2025-sp    YDSH     320    Responses to the Holocaust
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12316                    Same as INFO 303. See INFO 303.     3 hours.
# 12317                    Same as INFO 303. See INFO 303.     3 hours.
# 12318  Continuation of YDSH 101 focusing on comprehen...     4 hours.
# 12319  Continuation of YDSH 101 focusing on comprehen...     4 hours.
# 12320  Same as CWL 320, ENGL 359, JS 320, and REL 320...     3 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12316                    Same as INFO 303. See INFO 303.
# 12317                    Same as INFO 303. See INFO 303.
# 12318                                                NaN
# 12319                                                NaN
# 12320  Same as CWL 320, ENGL 359, JS 320, and REL 320...
#
#                                        Degree Attributes  ... Section Status  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# ...                                                  ...  ...            ...
# 12316                       Advanced Composition course.  ...              A
# 12317                       Advanced Composition course.  ...              A
# 12318                                                NaN  ...              A
# 12319                                                NaN  ...              A
# 12320  Humanities - Lit & Arts, and Cultural Studies ...  ...              A
#
#        Enrollment Status                   Type Type Code Start Time  \
# 0                 Closed     Lecture-Discussion       LCD   02:00 PM
# 1                   Open  Discussion/Recitation       DIS   09:00 AM
# 2                   Open  Discussion/Recitation       DIS   10:00 AM
# 3                   Open  Discussion/Recitation       DIS   11:00 AM
# 4                   Open  Discussion/Recitation       DIS   12:00 PM
# ...                  ...                    ...       ...        ...
# 12316             Closed                Lecture       LEC   11:00 AM
# 12317             Closed                Lecture       LEC   12:30 PM
# 12318             Closed                 Online       ONL   09:00 AM
# 12319             Closed                 Online       ONL   09:00 AM
# 12320      CrossListOpen     Lecture-Discussion       LCD   12:30 PM
#
#        End Time Days of Week  Room                       Building  \
# 0      03:20 PM           MW   304               Noyes Laboratory
# 1      09:50 AM            F  1030  Literatures, Cultures, & Ling
# 2      10:50 AM            F  1030  Literatures, Cultures, & Ling
# 3      11:50 AM            F  1030  Literatures, Cultures, & Ling
# 4      12:50 PM            F  1030  Literatures, Cultures, & Ling
# ...         ...          ...   ...                            ...
# 12316  12:15 PM           TR   204        Transportation Building
# 12317  01:45 PM           TR    11            Psychology Building
# 12318  10:00 AM            F   NaN                            NaN
# 12319  10:30 AM           TR   NaN                            NaN
# 12320  01:50 PM           TR  1306             Everitt Laboratory
#
#              Instructors
# 0                Geng, C
# 1      Siglos, D;Wang, Y
# 2      Siglos, D;Wang, Y
# 3       Kim, G;Siglos, D
# 4       Kim, G;Siglos, D
# ...                  ...
# 12316             Liu, N
# 12317      Kapczynski, L
# 12318          Butler, D
# 12319          Butler, D
# 12320        Grossman, R
#
# [12321 rows x 27 columns]

# %% [markdown]
# ## 🔬 Test Case Checkpoint 🔬
#
# Throughout the lab, we will have "checkpoints" at key points.  Most checkpoints will include **test cases** that verify that your notebook appears to be correct.
#
# - The test cases are **NOT** a guarantee that everything is perfect, but we try our very best to catch any common mistakes you might make!
# - If you see `AssertionError` error message when running the test case, we provide a helpful hint on what may not be correct.
# - If you see a party popper emoji and a message that all tests pass, you passed the checkpoint!
# - **Checkpoints** are a good time to check with your group to make everyone gets to the checkpoint together!

# %%
## == CHECKPOINT TEST CASES for Part 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "Did you define a variable called df?"
assert( len(df) == 12321 ), "It looks like you did not import the correct dataset?"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: STAT / CS / IS Majors
#
# Data Science DISCOVERY is a unique course that is cross-listed across three departments: Statistics, Computer Science, and Information Sciences.  Let's explore courses from all three of those subjects!

# %% [markdown]
# ### Puzzle 3.1
#
# Select only the rows that have a `Subject` of `STAT`.  Assign this to the variable name `df_STAT` instead of the usual `df`.
# - Make sure your result contains only statistics courses!

# %%
df_STAT = df[df["Subject"]=="STAT"]
df_STAT
# Out:
#        Year    Term YearTerm Subject  Number                           Name  \
# 11549  2025  Spring  2025-sp    STAT     100                     Statistics
# 11550  2025  Spring  2025-sp    STAT     100                     Statistics
# 11551  2025  Spring  2025-sp    STAT     107         Data Science Discovery
# 11552  2025  Spring  2025-sp    STAT     107         Data Science Discovery
# 11553  2025  Spring  2025-sp    STAT     107         Data Science Discovery
# ...     ...     ...      ...     ...     ...                            ...
# 11710  2025  Spring  2025-sp    STAT     587     Hierarchical Linear Models
# 11711  2025  Spring  2025-sp    STAT     590  Individual Study and Research
# 11712  2025  Spring  2025-sp    STAT     593                STAT Internship
# 11713  2025  Spring  2025-sp    STAT     593                STAT Internship
# 11714  2025  Spring  2025-sp    STAT     599                Thesis Research
#
#                                              Description    Credit Hours  \
# 11549  First course in probability and statistics at ...        3 hours.
# 11550  First course in probability and statistics at ...        3 hours.
# 11551  Data Science Discovery is the intersection of ...        4 hours.
# 11552  Data Science Discovery is the intersection of ...        4 hours.
# 11553  Data Science Discovery is the intersection of ...        4 hours.
# ...                                                  ...             ...
# 11710       Same as PSYC 587 and EPSY 587. See EPSY 587.        4 hours.
# 11711  Directed reading and research. Approved for le...   0 TO 8 hours.
# 11712  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 11713  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 11714  Approved for S/U grading only. May be repeated...  0 TO 16 hours.
#
#                                             Section Info  \
# 11549  Credit is not given for both STAT 100 and any ...
# 11550  Credit is not given for both STAT 100 and any ...
# 11551                         Same as CS 107 and IS 107.
# 11552                         Same as CS 107 and IS 107.
# 11553                         Same as CS 107 and IS 107.
# ...                                                  ...
# 11710       Same as PSYC 587 and EPSY 587. See EPSY 587.
# 11711  Approved for letter and S/U grading. May be re...
# 11712  Approved for letter and S/U grading. Prerequis...
# 11713  Approved for letter and S/U grading. Prerequis...
# 11714  Approved for S/U grading only. May be repeated...
#
#                       Degree Attributes  ... Section Status  \
# 11549  Quantitative Reasoning I course.  ...              A
# 11550  Quantitative Reasoning I course.  ...              A
# 11551  Quantitative Reasoning I course.  ...              A
# 11552  Quantitative Reasoning I course.  ...              A
# 11553  Quantitative Reasoning I course.  ...              A
# ...                                 ...  ...            ...
# 11710                               NaN  ...              A
# 11711                               NaN  ...              A
# 11712                               NaN  ...              A
# 11713                               NaN  ...              A
# 11714                               NaN  ...              A
#
#                 Enrollment Status                   Type Type Code Start Time  \
# 11549           Open (Restricted)                Lecture       LEC   02:00 PM
# 11550                      Closed                 Online       ONL   ARRANGED
# 11551  CrossListOpen (Restricted)                Lecture       LEC   10:00 AM
# 11552  CrossListOpen (Restricted)                Lecture       LEC   12:00 PM
# 11553               CrossListOpen  Laboratory-Discussion       LBD   11:00 AM
# ...                           ...                    ...       ...        ...
# 11710                      Closed                Lecture       LEC   02:00 PM
# 11711                      Closed      Independent Study       IND   ARRANGED
# 11712           Open (Restricted)             Internship       INT   ARRANGED
# 11713           Open (Restricted)             Internship       INT   ARRANGED
# 11714                      Closed      Independent Study       IND   ARRANGED
#
#        End Time Days of Week   Room                       Building  \
# 11549  02:50 PM          MWF  THEAT                   Lincoln Hall
# 11550       NaN          NaN    NaN                            NaN
# 11551  10:50 AM          MWF  THEAT                   Lincoln Hall
# 11552  12:50 PM          MWF  THEAT                   Lincoln Hall
# 11553  12:20 PM            R    G20  Literatures, Cultures, & Ling
# ...         ...          ...    ...                            ...
# 11710  03:20 PM           MW    242             Education Building
# 11711       NaN          NaN    NaN                            NaN
# 11712       NaN          NaN    NaN                            NaN
# 11713       NaN          NaN    NaN                            NaN
# 11714       NaN          NaN    NaN                            NaN
#
#                                              Instructors
# 11549                                             Rao, V
# 11550                                             Rao, V
# 11551                  Fagen-Ulmschneider, W;Flanagan, K
# 11552                  Fagen-Ulmschneider, W;Flanagan, K
# 11553                                                NaN
# ...                                                  ...
# 11710                                           Zhang, J
# 11711                                                NaN
# 11712  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 11713  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 11714                                                NaN
#
# [166 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.2
#
# Select only the rows that have a `Subject` of `CS`.  Assign this to the variable name `df_CS` instead of the usual `df`.
# - Make sure your result contains only computer science courses!

# %%
df_CS = df[df["Subject"]=="CS"]
df_CS
# Out:
#       Year    Term YearTerm Subject  Number                              Name  \
# 2997  2025  Spring  2025-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 2998  2025  Spring  2025-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 2999  2025  Spring  2025-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3000  2025  Spring  2025-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3001  2025  Spring  2025-sp      CS     101  Intro Computing: Engrg &amp; Sci
# ...    ...     ...      ...     ...     ...                               ...
# 3414  2025  Spring  2025-sp      CS     598                    Special Topics
# 3415  2025  Spring  2025-sp      CS     598                    Special Topics
# 3416  2025  Spring  2025-sp      CS     598                    Special Topics
# 3417  2025  Spring  2025-sp      CS     598                    Special Topics
# 3418  2025  Spring  2025-sp      CS     599                   Thesis Research
#
#                                             Description    Credit Hours  \
# 2997  Fundamental principles, concepts, and methods ...        3 hours.
# 2998  Fundamental principles, concepts, and methods ...        3 hours.
# 2999  Fundamental principles, concepts, and methods ...        3 hours.
# 3000  Fundamental principles, concepts, and methods ...        3 hours.
# 3001  Fundamental principles, concepts, and methods ...        3 hours.
# ...                                                 ...             ...
# 3414  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3415  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3416  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3417  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3418    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 2997  Prerequisite: One of MATH 220 or MATH 221 or M...
# 2998  Prerequisite: One of MATH 220 or MATH 221 or M...
# 2999  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3000  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3001  Prerequisite: One of MATH 220 or MATH 221 or M...
# ...                                                 ...
# 3414  May be repeated in the same or separate terms ...
# 3415  May be repeated in the same or separate terms ...
# 3416  May be repeated in the same or separate terms ...
# 3417  May be repeated in the same or separate terms ...
# 3418    Approved for S/U grading only. May be repeated.
#
#                       Degree Attributes  ... Section Status  \
# 2997  Quantitative Reasoning II course.  ...              A
# 2998  Quantitative Reasoning II course.  ...              A
# 2999  Quantitative Reasoning II course.  ...              A
# 3000  Quantitative Reasoning II course.  ...              A
# 3001  Quantitative Reasoning II course.  ...              A
# ...                                 ...  ...            ...
# 3414                                NaN  ...              A
# 3415                                NaN  ...              A
# 3416                                NaN  ...              A
# 3417                                NaN  ...              A
# 3418                                NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 2997  Open (Restricted)                Lecture       LEC   03:00 PM  03:50 PM
# 2998             Closed  Laboratory-Discussion       LBD   04:00 PM  05:50 PM
# 2999             Closed  Laboratory-Discussion       LBD   09:00 AM  10:50 AM
# 3000               Open  Laboratory-Discussion       LBD   11:00 AM  12:50 PM
# 3001             Closed  Laboratory-Discussion       LBD   01:00 PM  02:50 PM
# ...                 ...                    ...       ...        ...       ...
# 3414             Closed                Lecture       LEC   12:30 PM  01:50 PM
# 3415             Closed     Lecture-Discussion       S17   09:30 AM  10:45 AM
# 3416             Closed     Lecture-Discussion       S13   11:00 AM  12:15 PM
# 3417             Closed     Lecture-Discussion        S5   02:00 PM  03:15 PM
# 3418             Closed      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week  Room                        Building            Instructors
# 2997           MW   AUD           Foellinger Auditorium  Butler, L;Ritschel, N
# 2998            M   432                          Armory  Butler, L;Ritschel, N
# 2999            T  2406      Siebel Center for Comp Sci  Butler, L;Ritschel, N
# 3000            T  2406      Siebel Center for Comp Sci  Butler, L;Ritschel, N
# 3001            T  2406      Siebel Center for Comp Sci  Butler, L;Ritschel, N
# ...           ...   ...                             ...                    ...
# 3414           TR  3020  Electrical & Computer Eng Bldg               Gupta, S
# 3415           TR   218      Siebel Center for Comp Sci              August, T
# 3416           WF   218      Siebel Center for Comp Sci                Yuan, W
# 3417           TR  1310     Digital Computer Laboratory                Park, Y
# 3418          NaN   NaN                             NaN                    NaN
#
# [422 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.3
#
# Select only the rows that have a `Subject` of `IS`.  Assign this to the variable name `df_IS` instead of the usual `df`.
# - Make sure your result contains only information science courses!

# %%
df_IS = df[df["Subject"]=="IS"]
df_IS
# Out:
#       Year    Term YearTerm Subject  Number  \
# 6404  2025  Spring  2025-sp      IS     100
# 6405  2025  Spring  2025-sp      IS     101
# 6406  2025  Spring  2025-sp      IS     101
# 6407  2025  Spring  2025-sp      IS     101
# 6408  2025  Spring  2025-sp      IS     101
# ...    ...     ...      ...     ...     ...
# 6732  2025  Spring  2025-sp      IS     599
# 6733  2025  Spring  2025-sp      IS     599
# 6734  2025  Spring  2025-sp      IS     599
# 6735  2025  Spring  2025-sp      IS     599
# 6736  2025  Spring  2025-sp      IS     599
#
#                                                   Name  \
# 6404  Exploring the iSchool with a Human-Centered Lens
# 6405              Introduction to Information Sciences
# 6406              Introduction to Information Sciences
# 6407              Introduction to Information Sciences
# 6408              Introduction to Information Sciences
# ...                                                ...
# 6732                                   Thesis Research
# 6733                                   Thesis Research
# 6734                                   Thesis Research
# 6735                                   Thesis Research
# 6736                                   Thesis Research
#
#                                             Description    Credit Hours  \
# 6404  This course introduces students to the School ...        1 hours.
# 6405  This course provides an introduction to the fi...        3 hours.
# 6406  This course provides an introduction to the fi...        3 hours.
# 6407  This course provides an introduction to the fi...        3 hours.
# 6408  This course provides an introduction to the fi...        3 hours.
# ...                                                 ...             ...
# 6732  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6733  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6734  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6735  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6736  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 6404  Prerequisite: Restricted to Majors Only; First...
# 6405                                                NaN
# 6406                                                NaN
# 6407                                                NaN
# 6408                                                NaN
# ...                                                 ...
# 6732  0 to 16 graduate hours. No professional credit...
# 6733  0 to 16 graduate hours. No professional credit...
# 6734  0 to 16 graduate hours. No professional credit...
# 6735  0 to 16 graduate hours. No professional credit...
# 6736  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes  ... Section Status  \
# 6404                                 NaN  ...              A
# 6405  Social & Beh Sci - Soc Sci course.  ...              A
# 6406  Social & Beh Sci - Soc Sci course.  ...              A
# 6407  Social & Beh Sci - Soc Sci course.  ...              A
# 6408  Social & Beh Sci - Soc Sci course.  ...              A
# ...                                  ...  ...            ...
# 6732                                 NaN  ...              A
# 6733                                 NaN  ...              A
# 6734                                 NaN  ...              A
# 6735                                 NaN  ...              A
# 6736                                 NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 6404  Open (Restricted)     Lecture-Discussion       LCD   11:00 AM  11:50 AM
# 6405             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6406             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6407  Open (Restricted)  Discussion/Recitation       DIS   09:30 AM  10:50 AM
# 6408             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 6732               Open      Independent Study       IND   ARRANGED       NaN
# 6733               Open      Independent Study       IND   ARRANGED       NaN
# 6734               Open      Independent Study       IND   ARRANGED       NaN
# 6735               Open      Independent Study       IND   ARRANGED       NaN
# 6736               Open      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week Room                        Building   Instructors
# 6404            T  126  Grad Sch of Lib & Info Science      Kittl, K
# 6405            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# 6406            R   53  Grad Sch of Lib & Info Science     Pintar, J
# 6407            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# 6408            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# ...           ...  ...                             ...           ...
# 6732          NaN  NaN                             NaN     Torvik, V
# 6733          NaN  NaN                             NaN  Underwood, W
# 6734          NaN  NaN                             NaN      Huang, Y
# 6735          NaN  NaN                             NaN       Wang, Y
# 6736          NaN  NaN                             NaN    LeBlanc, Z
#
# [333 rows x 27 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES for Part 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_IS' in vars() ), "Make certain to name the IS courses df_IS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_CS to only CS courses."
assert( len(df_IS[df_IS.Subject != "IS"] ) == 0 ), "It looks like you did not subset df_IS to only IS courses."
assert( len(df_STAT) == 166 ), "It looks like you do not subset df_STAT correctly. Check your conditional statement."
assert( len(df_CS) == 422 ), "It looks like you do not subset df_CS correctly. Check your conditional statement."
assert( len(df_IS) == 333 ), "It looks like you do not subset df_IS correctly. Check your conditional statement."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 4: Your Major

# %% [markdown]
# In this part, you will be exploring **your major** using the Course Catalog dataset. This dataset contains sections of each course at UIUC.
#
# - Use the primary subject of your **current major** (or, if you're undeclared, your intended major) for this section.
# - Your answers will be different than the rest of your group!

# %% [markdown]
# ### Puzzle 4.1:
#
# Select only the rows that have a `Subject` of your current/intended major.  Assign this to the variable name `mydf` instead of `df`:

# %%
mydf =df[df["Subject"]=="HK"]
mydf
# Out:
#       Year    Term YearTerm Subject  Number                    Name  \
# 5878  2025  Spring  2025-sp      HK     100  Development Activities
# 5879  2025  Spring  2025-sp      HK     100  Development Activities
# 5880  2025  Spring  2025-sp      HK     100  Development Activities
# 5881  2025  Spring  2025-sp      HK     100  Development Activities
# 5882  2025  Spring  2025-sp      HK     100  Development Activities
# ...    ...     ...      ...     ...     ...                     ...
# 6140  2025  Spring  2025-sp      HK     590       Independent Study
# 6141  2025  Spring  2025-sp      HK     591                 Seminar
# 6142  2025  Spring  2025-sp      HK     594          Special Topics
# 6143  2025  Spring  2025-sp      HK     594          Special Topics
# 6144  2025  Spring  2025-sp      HK     599         Thesis Research
#
#                                             Description    Credit Hours  \
# 5878  Skills and knowledge essential for leisure-tim...   1 TO 2 hours.
# 5879  Skills and knowledge essential for leisure-tim...   1 TO 2 hours.
# 5880  Skills and knowledge essential for leisure-tim...   1 TO 2 hours.
# 5881  Skills and knowledge essential for leisure-tim...   1 TO 2 hours.
# 5882  Skills and knowledge essential for leisure-tim...   1 TO 2 hours.
# ...                                                 ...             ...
# 6140  Independent research on special projects. 2 or...   2 OR 4 hours.
# 6141  Lectures, discussions, and critiques on kinesi...        1 hours.
# 6142  Lecture course in topics of current interest; ...   1 TO 4 hours.
# 6143  Lecture course in topics of current interest; ...   1 TO 4 hours.
# 6144  Preparation of theses in health and kinesiolog...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 5878  Additional fees may apply. See Class Schedule....               NaN
# 5879  Additional fees may apply. See Class Schedule....               NaN
# 5880  Additional fees may apply. See Class Schedule....               NaN
# 5881  Additional fees may apply. See Class Schedule....               NaN
# 5882  Additional fees may apply. See Class Schedule....               NaN
# ...                                                 ...               ...
# 6140  2 or 4 graduate hours. No professional credit....               NaN
# 6141  1 graduate hour. No professional credit. Appro...               NaN
# 6142  1 to 4 graduate hours. No professional credit....               NaN
# 6143  1 to 4 graduate hours. No professional credit....               NaN
# 6144  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 5878  ...              A               Open          Laboratory       LAB
# 5879  ...              A             Closed          Laboratory       LAB
# 5880  ...              A             Closed          Laboratory       LAB
# 5881  ...              A             Closed          Laboratory       LAB
# 5882  ...              A             Closed          Laboratory       LAB
# ...   ...            ...                ...                 ...       ...
# 6140  ...              A             Closed   Independent Study       IND
# 6141  ...              A  Open (Restricted)             Seminar       SEM
# 6142  ...              A  Open (Restricted)  Lecture-Discussion       LCD
# 6143  ...              A  Open (Restricted)  Lecture-Discussion       LCD
# 6144  ...              A             Closed   Independent Study       IND
#
#      Start Time  End Time Days of Week  Room                       Building  \
# 5878   10:00 AM  10:50 AM           MW  1048  Campus Recreation Center East
# 5879   01:00 PM  02:20 PM           MW   ARR                     Freer Hall
# 5880   02:00 PM  03:20 PM           TR   ARR                     Freer Hall
# 5881   01:00 PM  02:20 PM           MW   ARR                     Freer Hall
# 5882   02:00 PM  03:20 PM           TR   ARR                     Freer Hall
# ...         ...       ...          ...   ...                            ...
# 6140   ARRANGED       NaN          NaN   NaN                            NaN
# 6141   12:00 PM  12:50 PM            F  2001                      Huff Hall
# 6142   02:00 PM  04:50 PM            W   166             Education Building
# 6143   12:00 PM  02:50 PM            W   255                     Freer Hall
# 6144   ARRANGED       NaN          NaN   NaN                            NaN
#
#                               Instructors
# 5878              Assis Alves Siqueira, V
# 5879                             Woods, M
# 5880                             Huang, P
# 5881                             Woods, M
# 5882                             Huang, P
# ...                                   ...
# 6140                                  NaN
# 6141                             Woods, A
# 6142  Amaral de Andrade Leao, O;Barnes, B
# 6143                          Senefeld, J
# 6144                                  NaN
#
# [267 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.2:
#
# Select **five random course sections** from your major, using `mydf` and pandas functions:

# %%
mydf.sample(n=5)
# Out:
#       Year    Term YearTerm Subject  Number  \
# 5931  2025  Spring  2025-sp      HK     106
# 5926  2025  Spring  2025-sp      HK     106
# 6076  2025  Spring  2025-sp      HK     423
# 5935  2025  Spring  2025-sp      HK     110
# 5986  2025  Spring  2025-sp      HK     208
#
#                                                    Name  \
# 5931                              Team Sport Activities
# 5926                              Team Sport Activities
# 6076  Social Marketing and Comm in Health Education ...
# 5935                                Contemporary Health
# 5986                     Introduction to Medical Ethics
#
#                                             Description   Credit Hours  \
# 5931  Skills and knowledge essential for leisure-tim...       1 hours.
# 5926  Skills and knowledge essential for leisure-tim...       1 hours.
# 6076  Examines the strategic integration of social m...  3 OR 4 hours.
# 5935  Examines concepts of health and health promoti...       3 hours.
# 5986  Course stresses normative bioethics: decisions...       3 hours.
#
#                                   Section Info  \
# 5931  May be repeated to a maximum of 2 hours.
# 5926  May be repeated to a maximum of 2 hours.
# 6076  3 undergraduate hours. 4 graduate hours.
# 5935                                       NaN
# 5986                                       NaN
#
#                        Degree Attributes  ... Section Status  \
# 5931                                 NaN  ...              A
# 5926                                 NaN  ...              A
# 6076                                 NaN  ...              A
# 5935  Social & Beh Sci - Soc Sci course.  ...              A
# 5986    Humanities - Hist & Phil course.  ...              A
#
#                Enrollment Status                   Type Type Code Start Time  \
# 5931                      Closed             Laboratory       LAB   11:00 AM
# 5926                      Closed             Laboratory       LAB   10:00 AM
# 6076  CrossListOpen (Restricted)                Lecture       LEC   03:30 PM
# 5935                        Open  Discussion/Recitation       DIS   01:00 PM
# 5986                        Open                 Online       ONL   ARRANGED
#
#       End Time Days of Week  Room                        Building  \
# 5931  11:50 AM           TR  1003   Campus Recreation Center East
# 5926  10:50 AM           TR  GYM2  Activities & Recreation Center
# 6076  04:50 PM           MW   136                          Armory
# 5935  01:50 PM            W  3019                       Huff Hall
# 5986       NaN          NaN   NaN                             NaN
#
#                Instructors
# 5931           Harrison, Z
# 5926              Huang, H
# 6076  Kelley-Freiburger, B
# 5935       Diaz, K;Riis, J
# 5986               Fink, E
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.3:
#
# Select **the seven course sections with the smallest course number** from your major:

# %%
mydf=df.nsmallest(7,'Number')

# %%
### Puzzle 4.4:

Select **the nine course sections with the highest course number** from your major:
# Out:
#   Cell In[179], line 3
#     Select **the nine course sections with the highest course number** from your major:
#                  ^
# SyntaxError: invalid syntax

# %%
mydf= df.nlargest(9,"Number")

# %% [markdown]
# ### Puzzle 4.5:
#
# Select **a random sample of 10% of the course sections** from your major:

# %%
mydf= df.sample(frac=.10)

# %% [markdown]
# ### ✔️ Checkpoint ✔️
#
# There are no test cases for Part 4 (since everyone has different majors), but go double check your work! Share your results with your group. After that, there's just one section left to go! :)

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 5: Growth of the IS major
#
# The IS major is still a new relatively new major here at UIUC. The final puzzle is for you to analyze how much the IS major has grown since 2019.

# %% [markdown]
# ### Puzzle 5.1: Loading the Course Catalog Dataset from 2019
#
# Using the name `df2019` instead of `df`, load the "Fall 2019 Course Catalog Dataset" that can be found at the following URL:
# ```
# http://waf-server-01.cs.illinois.edu/static/course-catalog-fa19.csv
# ```

# %%
df2019 = pd.read_csv("http://waf-server-01.cs.illinois.edu/static/course-catalog-fa19.csv")
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %% [markdown]
# ### Puzzle 5.2: Data Analysis
#
# In the following cells,
# - Using the `df2019` dataset, select the rows where the subject is `IS`.
# - Using the `df` dataset (this is the entire dataset containing the most recent data), select the rows where the subject is `IS`.
# - Complete the reflection question below (Puzzle 5.3).  Feel free to write more code to answer it. Remember to work and chat with your group!

# %%
df2019= df2019[df2019["Subject"] == "IS"]
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 4843  2019  Fall  2019-fa      IS     107
# 4844  2019  Fall  2019-fa      IS     199
# 4845  2019  Fall  2019-fa      IS     202
# 4846  2019  Fall  2019-fa      IS     310
# 4847  2019  Fall  2019-fa      IS     351
# ...    ...   ...      ...     ...     ...
# 4930  2019  Fall  2019-fa      IS     591
# 4931  2019  Fall  2019-fa      IS     592
# 4932  2019  Fall  2019-fa      IS     593
# 4933  2019  Fall  2019-fa      IS     594
# 4934  2019  Fall  2019-fa      IS     599
#
#                                              Name  \
# 4843                       Data Science Discovery
# 4844                   Undergraduate Open Seminar
# 4845                     Social Aspects Info Tech
# 4846                  Computing in the Humanities
# 4847  The Design of Usable Information Interfaces
# ...                                           ...
# 4930                                    Practicum
# 4931                            Independent Study
# 4932                                  CAS Project
# 4933                Information Sciences Practice
# 4934                              Thesis Research
#
#                                             Description    Credit Hours  \
# 4843          Same as CS 107 and STAT 107. See STAT 107        4 hours.
# 4844       Undergraduate Open Seminar. May be repeated.   1 TO 5 hours.
# 4845       Same as INFO 202 and MACS 202. See INFO 202.        3 hours.
# 4846  Explores use and application of technology to ...        3 hours.
# 4847  Examines issues of Human Computer Interaction ...        3 hours.
# ...                                                 ...             ...
# 4930  Supervised field experience of professional-le...        2 hours.
# 4931  Permits the intermediate or advanced student o...   2 TO 4 hours.
# 4932  Individual study of a problem in library and i...   0 TO 8 hours.
# 4933  Full-time or part-time practice of of any info...        0 hours.
# 4934  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 4843          Same as CS 107 and STAT 107. See STAT 107
# 4844                                                NaN
# 4845       Same as INFO 202 and MACS 202. See INFO 202.
# 4846                                                NaN
# 4847                  Prerequisite: Sophomore standing.
# ...                                                 ...
# 4930  2 graduate hours. No professional credit. Appr...
# 4931  2 to 4 graduate hours. No professional credit....
# 4932  0 to 8 graduate hours. No professional credit....
# 4933  0 graduate hours. No professional credit. Appr...
# 4934  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes
# 4843    Quantitative Reasoning I course.
# 4844                                 NaN
# 4845  Social & Beh Sci - Soc Sci course.
# 4846                                 NaN
# 4847                                 NaN
# ...                                  ...
# 4930                                 NaN
# 4931                                 NaN
# 4932                                 NaN
# 4933                                 NaN
# 4934                                 NaN
#
# [92 rows x 10 columns]

# %%
df = df[df["Subject"] == "IS"]
df
# Out:
#       Year    Term YearTerm Subject  Number  \
# 6404  2025  Spring  2025-sp      IS     100
# 6405  2025  Spring  2025-sp      IS     101
# 6406  2025  Spring  2025-sp      IS     101
# 6407  2025  Spring  2025-sp      IS     101
# 6408  2025  Spring  2025-sp      IS     101
# ...    ...     ...      ...     ...     ...
# 6732  2025  Spring  2025-sp      IS     599
# 6733  2025  Spring  2025-sp      IS     599
# 6734  2025  Spring  2025-sp      IS     599
# 6735  2025  Spring  2025-sp      IS     599
# 6736  2025  Spring  2025-sp      IS     599
#
#                                                   Name  \
# 6404  Exploring the iSchool with a Human-Centered Lens
# 6405              Introduction to Information Sciences
# 6406              Introduction to Information Sciences
# 6407              Introduction to Information Sciences
# 6408              Introduction to Information Sciences
# ...                                                ...
# 6732                                   Thesis Research
# 6733                                   Thesis Research
# 6734                                   Thesis Research
# 6735                                   Thesis Research
# 6736                                   Thesis Research
#
#                                             Description    Credit Hours  \
# 6404  This course introduces students to the School ...        1 hours.
# 6405  This course provides an introduction to the fi...        3 hours.
# 6406  This course provides an introduction to the fi...        3 hours.
# 6407  This course provides an introduction to the fi...        3 hours.
# 6408  This course provides an introduction to the fi...        3 hours.
# ...                                                 ...             ...
# 6732  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6733  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6734  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6735  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6736  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 6404  Prerequisite: Restricted to Majors Only; First...
# 6405                                                NaN
# 6406                                                NaN
# 6407                                                NaN
# 6408                                                NaN
# ...                                                 ...
# 6732  0 to 16 graduate hours. No professional credit...
# 6733  0 to 16 graduate hours. No professional credit...
# 6734  0 to 16 graduate hours. No professional credit...
# 6735  0 to 16 graduate hours. No professional credit...
# 6736  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes  ... Section Status  \
# 6404                                 NaN  ...              A
# 6405  Social & Beh Sci - Soc Sci course.  ...              A
# 6406  Social & Beh Sci - Soc Sci course.  ...              A
# 6407  Social & Beh Sci - Soc Sci course.  ...              A
# 6408  Social & Beh Sci - Soc Sci course.  ...              A
# ...                                  ...  ...            ...
# 6732                                 NaN  ...              A
# 6733                                 NaN  ...              A
# 6734                                 NaN  ...              A
# 6735                                 NaN  ...              A
# 6736                                 NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 6404  Open (Restricted)     Lecture-Discussion       LCD   11:00 AM  11:50 AM
# 6405             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6406             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6407  Open (Restricted)  Discussion/Recitation       DIS   09:30 AM  10:50 AM
# 6408             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 6732               Open      Independent Study       IND   ARRANGED       NaN
# 6733               Open      Independent Study       IND   ARRANGED       NaN
# 6734               Open      Independent Study       IND   ARRANGED       NaN
# 6735               Open      Independent Study       IND   ARRANGED       NaN
# 6736               Open      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week Room                        Building   Instructors
# 6404            T  126  Grad Sch of Lib & Info Science      Kittl, K
# 6405            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# 6406            R   53  Grad Sch of Lib & Info Science     Pintar, J
# 6407            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# 6408            R  12A  Grad Sch of Lib & Info Science     Pintar, J
# ...           ...  ...                             ...           ...
# 6732          NaN  NaN                             NaN     Torvik, V
# 6733          NaN  NaN                             NaN  Underwood, W
# 6734          NaN  NaN                             NaN      Huang, Y
# 6735          NaN  NaN                             NaN       Wang, Y
# 6736          NaN  NaN                             NaN    LeBlanc, Z
#
# [333 rows x 27 columns]

# %%
# Feel free to add more code cells if needed by hovering over the area below the cell and pressing "+ Code"!

# %% [markdown]
# ### Puzzle 5.3: Reflection on this Data Analysis
#
# In the follow cell, **explain what you found** related to the growth of the IS program. In your explanation, make sure to **use actual data** (ex: by how much did it grow?)

# %% [markdown]
# From 2019 to 2025, there are more rows of classes as there was only 92 and how there is 333 meaning that the program grew by a lot.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission

# %% [markdown]
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
